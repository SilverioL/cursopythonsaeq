# %%
# !python --version
# Out:
# Python 3.7.13

# %%
#exercício 01) Faça um progrma que leia 2 string e:

string_1 = input(" fale ai")
print(string_1)
string_2 = input(" só digitar")
print(string_2)
len(string_1) == len(string_2)
# Out:
#  fale ai100
# 100
#  só digitar00
# 00
# False

# %%
#exercício 02) Faça um programa que permita ao usuário digitar o seu nome e em seguida o mostre o mesmo conteúdo 

string_3 = input(" Digite seu nome ")
print(string_3)
print(string_3 .upper() [::-1])
# Out:
#  Digite seu nome 100
# 100
# 001

# %%
#exercício 03)

string_4 = input("vou pegar as quatro letras finais da frase ")
print(string_4[:-4])
print(string_4.title())
print(string_4.replace(" ", "espaço"))
# Out:
# vou pegar as quatro letras finais da frase 100
#
# 100
# 100

# %%
#exercício 04)

numinta = int(input("Digite um numero inteiro "))
numintb = int(input("Digite um numero inteiro "))
print(f"soma = {numinta+numintb}")
print(f"subtracao = {numinta-numintb}")
print(f"potenciacao = {numinta**numintb}")
print(f"media = {(numinta+numintb)/2}")
# Out:
# Digite um numero inteiro 10
# Digite um numero inteiro 12
# soma = 22
# subtracao = -2
# potenciacao = 1000000000000
# media = 11.0

# %%
#exercício 05)

raio = float(input("Digite o raio do circulo "))
area = (raio**2)*3.14
#print(f"A area do circulo é {area}")
print(area)
# Out:
# Digite o raio do circulo 10
# 314.0
